# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from Reading import read_and_smooth, our_lord_and_saviour_fourier

# %%
time1, red_ready, blue_ready = read_and_smooth("protufaza1.csv")
four, freqs, PDS = our_lord_and_saviour_fourier(time1, red_ready)


fig, ax = plt.subplots(figsize=[8,7])

plt.plot(freqs, PDS, color = "red")
plt.xlim(0, 100)
plt.xlabel("f(Hz)")
plt.ylabel("Amplituda (arbitrary unit)")

sub_axes = plt.axes([.3, .3, .5, .5]) 
sub_axes.plot(freqs, PDS, color = "red") 

sub_axes.set_xlim(0.4, 0.7)
sub_axes.set_xlabel("f(Hz)")
sub_axes.set_ylabel("Amplituda (arbitrary unit)")

#plt.savefig("OsnovniFTT.png")
# Out:
# Text(0, 0.5, 'Amplituda (arbitrary unit)')

# %%
indeks = np.where(PDS == max(PDS))[0]
2 * np.pi * abs(freqs[indeks][0])
# Out:
# 3.1939420534469134

# %%
time1, red_ready, blue_ready = read_and_smooth("protufaza2.csv")
four, freqs, PDS = our_lord_and_saviour_fourier(time1, red_ready)

indeks = np.where(PDS == max(PDS))[0]
print(2 * np.pi * abs(freqs[indeks][0]))

fig, ax = plt.subplots(figsize=[8,7])

plt.plot(freqs, PDS, color = "red")
plt.xlim(0, 100)
plt.xlabel("f(Hz)")
plt.ylabel("Amplituda (arbitrary unit)")

sub_axes = plt.axes([.3, .3, .5, .5]) 
sub_axes.plot(freqs, PDS, color = "red") 

sub_axes.set_xlim(0.4, 0.7)
sub_axes.set_xlabel("f(Hz)")
sub_axes.set_ylabel("Amplituda (arbitrary unit)")

#plt.savefig("OsnovniFTT.png")
# Out:
# 3.224347371359958
# Text(0, 0.5, 'Amplituda (arbitrary unit)')

# %%
indeks = np.where(PDS == max(PDS))[0]
2 * np.pi * abs(freqs[indeks][0])

# %%
time1, red_ready, blue_ready = read_and_smooth("protufaza150g1.csv")
four, freqs, PDS = our_lord_and_saviour_fourier(time1, red_ready)

indeks = np.where(PDS == max(PDS))[0]
print(2 * np.pi * abs(freqs[indeks][0]))

fig, ax = plt.subplots(figsize=[8,7])

plt.plot(freqs, PDS, color = "red")
plt.xlim(0, 100)
plt.xlabel("f(Hz)")
plt.ylabel("Amplituda (arbitrary unit)")

sub_axes = plt.axes([.3, .3, .5, .5]) 
sub_axes.plot(freqs, PDS, color = "red") 

sub_axes.set_xlim(0.4, 0.7)
sub_axes.set_xlabel("f(Hz)")
sub_axes.set_ylabel("Amplituda (arbitrary unit)")

#plt.savefig("OsnovniFTT.png")
# Out:
# 3.3060754855066143
# Text(0, 0.5, 'Amplituda (arbitrary unit)')

# %%
time1, red_ready, blue_ready = read_and_smooth("protufaza150g2.csv")
four, freqs, PDS = our_lord_and_saviour_fourier(time1, red_ready)

indeks = np.where(PDS == max(PDS))[0]
print(2 * np.pi * abs(freqs[indeks][0]))

fig, ax = plt.subplots(figsize=[8,7])

plt.plot(freqs, PDS, color = "red")
plt.xlim(0, 100)
plt.xlabel("f(Hz)")
plt.ylabel("Amplituda (arbitrary unit)")

sub_axes = plt.axes([.3, .3, .5, .5]) 
sub_axes.plot(freqs, PDS, color = "red") 

sub_axes.set_xlim(0.4, 0.7)
sub_axes.set_xlabel("f(Hz)")
sub_axes.set_ylabel("Amplituda (arbitrary unit)")

#plt.savefig("OsnovniFTT.png")
# Out:
# 3.3116158402689693
# Text(0, 0.5, 'Amplituda (arbitrary unit)')

# %%
time1, red_ready, blue_ready = read_and_smooth("protufaza250g1.csv")
four, freqs, PDS = our_lord_and_saviour_fourier(time1, red_ready)

indeks = np.where(PDS == max(PDS))[0]
print(2 * np.pi * abs(freqs[indeks][0]))

fig, ax = plt.subplots(figsize=[8,7])

plt.plot(freqs, PDS, color = "red")
plt.xlim(0, 100)
plt.xlabel("f(Hz)")
plt.ylabel("Amplituda (arbitrary unit)")

sub_axes = plt.axes([.3, .3, .5, .5]) 
sub_axes.plot(freqs, PDS, color = "red") 

sub_axes.set_xlim(0.4, 0.7)
sub_axes.set_xlabel("f(Hz)")
sub_axes.set_ylabel("Amplituda (arbitrary unit)")

#plt.savefig("OsnovniFTT.png")
# Out:
# 3.3495112827060805
# Text(0, 0.5, 'Amplituda (arbitrary unit)')

# %%
time1, red_ready, blue_ready = read_and_smooth("protufaza250g2.csv")
four, freqs, PDS = our_lord_and_saviour_fourier(time1, red_ready)

indeks = np.where(PDS == max(PDS))[0]
print(2 * np.pi * abs(freqs[indeks][0]))

fig, ax = plt.subplots(figsize=[8,7])

plt.plot(freqs, PDS, color = "red")
plt.xlim(0, 100)
plt.xlabel("f(Hz)")
plt.ylabel("Amplituda (arbitrary unit)")

sub_axes = plt.axes([.3, .3, .5, .5]) 
sub_axes.plot(freqs, PDS, color = "red") 

sub_axes.set_xlim(0.4, 0.7)
sub_axes.set_xlabel("f(Hz)")
sub_axes.set_ylabel("Amplituda (arbitrary unit)")

#plt.savefig("OsnovniFTT.png")
# Out:
# 3.3695266141533935
# Text(0, 0.5, 'Amplituda (arbitrary unit)')

# %%
time1, red_ready, blue_ready = read_and_smooth("protufaza200g1.csv")
four, freqs, PDS = our_lord_and_saviour_fourier(time1, red_ready)

indeks = np.where(PDS == max(PDS))[0]
print(2 * np.pi * abs(freqs[indeks][0]))

fig, ax = plt.subplots(figsize=[8,7])

plt.plot(freqs, PDS, color = "red")
plt.xlim(0, 100)
plt.xlabel("f(Hz)")
plt.ylabel("Amplituda (arbitrary unit)")

sub_axes = plt.axes([.3, .3, .5, .5]) 
sub_axes.plot(freqs, PDS, color = "red") 

sub_axes.set_xlim(0.4, 0.7)
sub_axes.set_xlabel("f(Hz)")
sub_axes.set_ylabel("Amplituda (arbitrary unit)")

#plt.savefig("OsnovniFTT.png")
# Out:
# 3.3308949995135286
# Text(0, 0.5, 'Amplituda (arbitrary unit)')

# %%
time1, red_ready, blue_ready = read_and_smooth("protufaza200g3.csv")
four, freqs, PDS = our_lord_and_saviour_fourier(time1, red_ready)

indeks = np.where(PDS == max(PDS))[0]
print(2 * np.pi * abs(freqs[indeks][0]))

fig, ax = plt.subplots(figsize=[8,7])

plt.plot(freqs, PDS, color = "red")
plt.xlim(0, 100)
plt.xlabel("f(Hz)")
plt.ylabel("Amplituda (arbitrary unit)")

sub_axes = plt.axes([.3, .3, .5, .5]) 
sub_axes.plot(freqs, PDS, color = "red") 

sub_axes.set_xlim(0.4, 0.7)
sub_axes.set_xlabel("f(Hz)")
sub_axes.set_ylabel("Amplituda (arbitrary unit)")

#plt.savefig("OsnovniFTT.png")
# Out:
# 3.369748233889444
# Text(0, 0.5, 'Amplituda (arbitrary unit)')

# %%
time1, red_ready, blue_ready = read_and_smooth("protufaza200g2.csv")
four, freqs, PDS = our_lord_and_saviour_fourier(time1, red_ready)

indeks = np.where(PDS == max(PDS))[0]
print(2 * np.pi * abs(freqs[indeks][0]))

fig, ax = plt.subplots(figsize=[8,7])

plt.plot(freqs, PDS, color = "red")
plt.xlim(0, 100)
plt.xlabel("f(Hz)")
plt.ylabel("Amplituda (arbitrary unit)")

sub_axes = plt.axes([.3, .3, .5, .5]) 
sub_axes.plot(freqs, PDS, color = "red") 

sub_axes.set_xlim(0.4, 0.7)
sub_axes.set_xlabel("f(Hz)")
sub_axes.set_ylabel("Amplituda (arbitrary unit)")

#plt.savefig("OsnovniFTT.png")
# Out:
# 3.371490207751385
# Text(0, 0.5, 'Amplituda (arbitrary unit)')

# %%
#bez masa

time1, red, blue = reading("protufaza1.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21

popt_red, pcov_red = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
popt_blue, pcov_blue = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, blue, p0)

plt.scatter(time1, red)
plt.scatter(time1, blue)

time = np.linspace(10, 30, 300)
A, omega, fi, B = popt_red
plt.plot(time, A*np.cos(omega*time + fi) + B, color="black")

A, omega, fi, B = popt_blue
plt.plot(time, A*np.cos(omega*time + fi) + B, color="black")
plt.xlim(10, 20)
# Out:
# (10, 20)

# %%
#bez masa

time1, red, blue = reading("protufaza2.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21

popt_red, pcov_red = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
popt_blue, pcov_blue = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, blue, p0)

plt.scatter(time1, red)
plt.scatter(time1, blue)

time = np.linspace(10, 30, 300)
A, omega, fi, B = popt_red
plt.plot(time, A*np.cos(omega*time + fi) + B, color="black")

A, omega, fi, B = popt_blue
plt.plot(time, A*np.cos(omega*time + fi) + B, color="black")
plt.xlim(10, 20)
# Out:
# (10, 20)

# %%
#m = 50 g i m = 100 g korumpirane

time1, red, blue = reading("protufaza150g1.csv")

p0 = max(red), 2*np.pi/(13.45-11.5), np.pi, 0.21

popt_red, pcov_red = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
popt_blue, pcov_blue = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, blue, p0)

plt.scatter(time1, red)
plt.scatter(time1, blue)

time = np.linspace(10, 30, 300)
A, omega, fi, B = popt_red
#plt.plot(time, A*np.cos(omega*time + fi) + B, color="black")

A, omega, fi, B = popt_blue
#plt.plot(time, A*np.cos(omega*time + fi) + B, color="black")

plt.plot(time, max(blue)*np.cos(omega*time + fi) + 0.2, color="black")
plt.xlim(10, 20)
plt.axvline(11.5)
plt.axvline(13.45) #okay ostali kompentente nisu bitne, frekvencija je dobra

# %%
popt_red, popt_blue
# Out:
# (array([ 0.04200561,  3.2257173 ,  1.91338858, -0.16023527]),
#  array([0.03418992, 3.21724578, 3.63601489, 0.29797326]))

# %%
max(blue)
# Out:
# 0.5685903
