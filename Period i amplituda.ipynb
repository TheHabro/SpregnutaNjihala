# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from Reading import read_and_smooth, our_lord_and_saviour_fourier
import json

# %%
amp = []
freq = []

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_8.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(8, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
#plt.axvline(18.06)
# Out:
# 3.19153868323524 3.202130350782173e-05 0.5208273966030047
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_2_1.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(8, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
#plt.axvline(18.06)
# Out:
# 3.19670789668651 3.9766321889314436e-05 0.33817563562664166
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_2_2.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(8, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
#plt.axvline(18.06)
# Out:
# 3.1974806886663103 3.565657418420157e-05 0.3139052755132167
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_3_1.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(8, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
#plt.axvline(18.06)
# Out:
# 3.1961584974400283 4.423918518094388e-05 0.34491401748922323
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_3_2.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(8, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1971620224306774 3.0815230454329525e-05 0.3301761323419167
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_3_2.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(8, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1971620224306774 3.0815230454329525e-05 0.3301761323419167
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_4_1.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(8, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1983065342458987 4.713603806316038e-05 0.2747877363848817
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_4_2.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(8, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1988535958456557 3.2417704629881005e-05 0.2514213286821753
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_4_3.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(8, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1990127508254407 8.759492566020037e-05 0.22218866594798908
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_5_1.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(10, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1958632775730806 4.059957538475908e-05 0.3650381705075177
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_5_2.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(10, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1967137450464134 3.0056555596545894e-05 0.34268430869479366
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_5_3.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(10, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1975869470308536 3.2349526347143054e-05 0.31138758345589923
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_6_1.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(10, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1911504016156593 3.527358736617454e-05 0.5121674755776481
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_6_2.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(10, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1929006787233534 2.7839365335679764e-05 0.47321768227525984
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_6_3.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(10, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1942834804955056 4.001631580881608e-05 0.409936901843978
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_7_1.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(10, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.196511977126699 3.9367030336772487e-05 0.3436905702087029
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_7_2.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(10, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.19719256052193 3.154467916304464e-05 0.32720830216078467
# (14, 18)

# %%
#more
time1, red, blue = read_and_smooth("veliki_otkloni_7_3.csv")

p0 = max(red), 2*np.pi/(18.06-16.1), 3*np.pi/2,-0.21
popt, pcov = curve_fit(lambda t, A, omega, fi, B: A*np.cos(omega*t + fi) + B, time1, red, p0)
print(popt[1], np.sqrt(pcov[1][1]), max(red))

amp.append(max(red))
freq.append(popt[1])

plt.scatter(time1, red, color="silver")
#plt.scatter(time1, blue)
time = np.linspace(10, 50, 450)
A, omega, fi, B = popt

plt.plot(time, A*np.cos(omega*time + fi) + B, color="red")
#plt.plot(time,max(blue)*np.cos(2*np.pi/(18.06-16.1)*time + 3*np.pi/2) + B, color="red")
plt.xlim(14, 18)

#plt.axvline(16.1)
# Out:
# 3.1978354229045256 4.747745637656773e-05 0.2922629494282886
# (14, 18)

# %%
#for i in range(0, len(amp)):
 #   print(amp[i], freq[i])

# %%
dikt = {"amps": amp, "freqs": freq}

with open("amp_freq.json", "w") as woof:
    to_write = json.dumps(dikt)
    woof.write(to_write)
